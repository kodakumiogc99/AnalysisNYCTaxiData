# %%
from datatable import dt, f, by, as_type
from datetime import datetime as d
from shapely.geometry import Point, shape, Polygon
import os, shutil, glob
import argparse
import dask.dataframe as dd
import pandas as pd
import matplotlib.pyplot as plt
import geopandas
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# /opt/conda/lib/python3.8/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
fold = '/BigData/BigData/HW1/*'
file = glob.glob(f'{fold}')
file
# Out:
# ['/BigData/BigData/HW1/yellow_tripdata_2009-03.csv',
#  '/BigData/BigData/HW1/yellow_tripdata_2009-02.csv',
#  '/BigData/BigData/HW1/yellow_tripdata_2009-01.csv']

# %%
frame = dt.Frame()
[frame.rbind(dt.fread(f, fill=True), force=True, bynames=True) for f in file]
columns = frame.names
columns
# Out:
# ('vendor_name',
#  'Trip_Pickup_DateTime',
#  'Trip_Dropoff_DateTime',
#  'Passenger_Count',
#  'Trip_Distance',
#  'Start_Lon',
#  'Start_Lat',
#  'Rate_Code',
#  'store_and_forward',
#  'End_Lon',
#  'End_Lat',
#  'Payment_Type',
#  'Fare_Amt',
#  'surcharge',
#  'mta_tax',
#  'Tip_Amt',
#  'Tolls_Amt',
#  'Total_Amt')

# %%
'''
Delete all NA row column and row
'''
del frame[:, 'store_and_forward']
del frame[:, 'Rate_Code']
del frame[:, 'mta_tax']
del frame[dt.rowall(f[:]==None),:]

# %%
frame[:,dt.update(Trip_Pickup_DateTime = dt.time.hour(f.Trip_Pickup_DateTime), \
                    Trip_Dropoff_DateTime = dt.time.hour(f.Trip_Dropoff_DateTime))]
frame
# Out:
# <Frame#7f2aa0b7d6c0 41859906x15>

# %%
from pyproj import CRS
crs = CRS('epsg:4326')
def cor2loc(df, lon_var, lat_var, name_var):
    local_df = df.copy()
    shape_df = geopandas.read_file('taxi_zones/taxi_zones.shp')
    shape_df.drop(['OBJECTID', 'Shape_Area', 'Shape_Leng', 'borough'], axis=1, inplace=True)
    shape_df = shape_df.to_crs(crs)
    
    try:
        local_gdf = geopandas.GeoDataFrame(local_df, crs=crs,
                                          geometry=[Point(xy) for xy in zip(local_df[lon_var], local_df[lat_var])])
        local_gdf = geopandas.sjoin(local_gdf, shape_df, how='left', op='within')
        local_gdf = local_gdf.drop('geometry', axis=1)
        local_gdf = local_gdf.drop('index_right', axis=1)
        local_gdf.rename(columns={'zone':f'{name_var}_Zone', 'LocationID':f'{name_var}_ID'}, inplace=True)
        return local_gdf
    except ValueError as ve:
        print(ve)
        print(ve.stacktrace())
        series = df[lon_var]
        return series

# %%
# Partition dataframe to multiple chunk
num_of_pool = 16
frame = frame.to_pandas()
n = frame.shape[0] // num_of_pool
list_frame = [frame[i:i+n] for i in range(0, frame.shape[0],n)]

# %%
# Mapping Lon and Lat to zone and location ID
from multiprocessing import Pool
from itertools import repeat
def multiple_mapping(num_of_pool, list_df,lon_var, lat_var, name_var):
    with Pool(num_of_pool) as pool:
        second_arg = lon_var
        third_arg = lat_var
        forth_arg = name_var
        new_list = pool.starmap(cor2loc, zip(list_df, repeat(second_arg), repeat(third_arg), repeat(forth_arg)))
    return new_list

# %%
list_frame = multiple_mapping(num_of_pool, list_frame, 'Start_Lon', 'Start_Lat', 'pick_up')
list_frame = multiple_mapping(num_of_pool, list_frame, 'End_Lon', 'End_Lat', 'drop_off')
# Out:
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# /opt/conda/lib/python3.8/multiprocessing/pool.py:125: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = (True, func(*args, **kwds))
# [        vendor_name  Trip_Pickup_DateTime  Trip_Dropoff_DateTime  \
#  0               CMT                    15                     15
#  1               CMT                     0                      0
#  2               DDS                    19                     20
#  3               CMT                    22                     22
#  4               CMT                    22                     23
#  ...             ...                   ...                    ...
#  2616239         CMT                    21                     22
#  2616240         DDS                    21                     21
#  2616241         CMT                    20                     20
#  2616242         CMT                    18                     18
#  2616243         CMT                    17                     17
#
#           Passenger_Count  Trip_Distance  Start_Lon  Start_Lat    End_Lon  \
#  0                      1            0.3 -73.970709  40.796382 -73.973602
#  1                      1            1.6 -74.007315  40.739964 -74.004717
#  2                      1            2.0 -73.976375  40.756729 -73.954439
#  3                      3            1.6 -73.990625  40.751453 -74.008427
#  4                      2            3.8 -73.993798  40.734164 -73.958812
#  ...                  ...            ...        ...        ...        ...
#  2616239                2            1.1 -73.953239  40.779957 -73.955846
#  2616240                2            2.2 -73.945982  40.777842 -73.967255
#  2616241                1            2.7 -73.984301  40.780015 -73.994844
#  2616242                1            0.3 -73.994110  40.751030 -73.998071
#  2616243                1            1.2 -73.991239  40.734946 -73.980280
#
#             End_Lat Payment_Type  Fare_Amt  surcharge  Tip_Amt  Tolls_Amt  \
#  0        40.792058         Cash       4.1        0.0      0.0        0.0
#  1        40.751879         Cash       7.0        0.0      0.0        0.0
#  2        40.767205         CASH       8.1        0.5      0.0        0.0
#  3        40.746579         Cash       7.0        0.0      0.0        0.0
#  4        40.769911         Cash      12.6        0.0      0.0        0.0
#  ...            ...          ...       ...        ...      ...        ...
#  2616239  40.767787         Cash       5.8        0.0      0.0        0.0
#  2616240  40.756029         CASH       7.7        0.5      0.0        0.0
#  2616241  40.750486         Cash       9.4        0.0      0.0        0.0
#  2616242  40.754170         Cash       4.3        0.0      0.0        0.0
#  2616243  40.745877         Cash       7.1        0.0      0.0        0.0
#
#           Total_Amt                   pick_up_Zone  pick_up_ID  \
#  0              4.1               Manhattan Valley       151.0
#  1              7.0  Meatpacking/West Village West       158.0
#  2              8.6                 Midtown Center       161.0
#  3              7.0               Garment District       100.0
#  4             12.6        Greenwich Village North       113.0
#  ...            ...                            ...         ...
#  2616239        5.8          Upper East Side North       236.0
#  2616240        8.2                 Yorkville East       262.0
#  2616241        9.4            Lincoln Square West       143.0
#  2616242        4.3   Penn Station/Madison Sq West       186.0
#  2616243        7.1        Greenwich Village North       113.0
#
#                           drop_off_Zone  drop_off_ID
#  0                Upper West Side North        238.0
#  1            West Chelsea/Hudson Yards        246.0
#  2                      Lenox Hill East        140.0
#  3            West Chelsea/Hudson Yards        246.0
#  4                      Lenox Hill West        141.0
#  ...                                ...          ...
#  2616239                Lenox Hill East        140.0
#  2616240  Sutton Place/Turtle Bay North        229.0
#  2616241                   East Chelsea         68.0
#  2616242                   East Chelsea         68.0
#  2616243                    Murray Hill        170.0
#
#  [2616245 rows x 19 columns],
#          vendor_name  Trip_Pickup_DateTime  Trip_Dropoff_DateTime  \
#  2616244         CMT                    23                     23
#  2616245         CMT                     0                      0
#  2616246         CMT                    12                     13
#  2616247         CMT                    17                     17
#  2616248         CMT                     2                      2
#  ...             ...                   ...                    ...
#  5232483         CMT                     8                      8
#  5232484         CMT                    23                     23
#  5232485         CMT                    17                     17
#  5232486         CMT                     9                      9
#  5232487         CMT                    14                     14
#
#           Passenger_Count  Trip_Distance  Start_Lon  Start_Lat    End_Lon  \
#  2616244                1            2.8 -73.979688  40.752251 -73.948924
#  2616245                1            2.4 -73.958703  40.716920 -73.950893
#  2616246                1            1.5 -73.995997  40.743438 -73.978151
#  2616247                3            4.1 -73.993253  40.692781 -73.992018
#  2616248                1            0.9 -74.016789  40.757739 -74.016789
#  ...                  ...            ...        ...        ...        ...
#  5232483                1            0.9 -74.003576  40.731881 -74.000920
#  5232484                1            1.6 -73.953664  40.766926 -73.941981
#  5232485                1            1.1 -73.962143  40.779225 -73.973121
#  5232486                1            1.7 -73.988664  40.731576 -73.995708
#  5232487                1            3.5 -73.994808  40.725342 -73.966270
#
#             End_Lat Payment_Type  Fare_Amt  surcharge  Tip_Amt  Tolls_Amt  \
#  2616244  40.777459       Credit       9.0        0.0      1.8        0.0
#  2616245  40.727541         Cash       7.8        0.0      0.0        0.0
#  2616246  40.751509         Cash       6.9        0.0      0.0        0.0
#  2616247  40.734991         Cash      15.9        0.0      0.0        0.0
#  2616248  40.757739         Cash       5.0        0.0      0.0        0.0
#  ...            ...          ...       ...        ...      ...        ...
#  5232483  40.721094       Credit       4.9        0.0      1.0        0.0
#  5232484  40.786956         Cash       6.6        0.0      0.0        0.0
#  5232485  40.763836         Cash       7.5        0.0      0.0        0.0
#  5232486  40.746574         Cash       8.1        0.0      0.0        0.0
#  5232487  40.761691         Cash      12.9        0.0      0.0        0.0
#
#           Total_Amt               pick_up_Zone  pick_up_ID  \
#  2616244       10.8                Murray Hill       170.0
#  2616245        7.8  Williamsburg (North Side)       255.0
#  2616246        6.9                   Flatiron        90.0
#  2616247       15.9           Brooklyn Heights        33.0
#  2616248        5.0                        NaN         NaN
#  ...            ...                        ...         ...
#  5232483        5.9               West Village       249.0
#  5232484        6.6            Lenox Hill East       140.0
#  5232485        7.5               Central Park        43.0
#  5232486        8.1               East Village        79.0
#  5232487       12.9    Greenwich Village South       114.0
#
#                     drop_off_Zone  drop_off_ID
#  2616244           Yorkville East        262.0
#  2616245               Greenpoint        112.0
#  2616246              Murray Hill        170.0
#  2616247  Greenwich Village North        113.0
#  2616248                      NaN          NaN
#  ...                          ...          ...
#  5232483                     SoHo        211.0
#  5232484        East Harlem South         75.0
#  5232485            Midtown North        163.0
#  5232486                 Flatiron         90.0
#  5232487          Lenox Hill West        141.0
#
#  [2616244 rows x 19 columns],
#          vendor_name  Trip_Pickup_DateTime  Trip_Dropoff_DateTime  \
#  5232488         CMT                    12                     12
#  5232489         CMT                    18                     18
#  5232490         CMT                     0                      0
#  5232491         CMT                    14                     14
#  5232492         CMT                    11                     11
#  ...             ...                   ...                    ...
#  7848727         VTS                    13                     14
#  7848728         VTS                    20                     20
#  7848729         VTS                    12                     12
#  7848730         VTS                    17                     17
#  7848731         CMT                    23                     23
#
#           Passenger_Count  Trip_Distance  Start_Lon  Start_Lat    End_Lon  \
#  5232488                1           1.70 -73.988777  40.736797 -73.972908
#  5232489                1           0.70 -73.947864  40.770733 -73.955852
#  5232490                1           8.00 -74.001527  40.731005 -74.025915
#  5232491                1           5.20 -73.975918  40.781414 -74.001684
#  5232492                1           1.20 -73.993393  40.749837 -73.987299
#  ...                  ...            ...        ...        ...        ...
#  7848727                2           2.45 -73.991233  40.751172 -73.982532
#  7848728                2           1.12 -73.980078  40.739143 -73.993072
#  7848729                1           1.11 -73.965053  40.759437 -73.972707
#  7848730                1           1.71 -74.000877  40.741998 -73.979915
#  7848731                1           1.40 -73.988475  40.764061 -74.004485
#
#             End_Lat Payment_Type  Fare_Amt  surcharge  Tip_Amt  Tolls_Amt  \
#  5232488  40.758771         Cash       6.9        0.0      0.0       0.00
#  5232489  40.764179         Cash       7.1        0.0      0.0       0.00
#  5232490  40.640048         Cash      19.8        0.0      0.0       4.15
#  5232491  40.719699         Cash      23.3        0.0      0.0       0.00
#  5232492  40.742761         Cash       6.9        0.0      0.0       0.00
#  ...            ...          ...       ...        ...      ...        ...
#  7848727  40.767997         CASH      12.1        0.0      0.0       0.00
#  7848728  40.733563       Credit       6.9        0.5      2.0       0.00
#  7848729  40.764155       Credit       5.3        0.0      1.0       0.00
#  7848730  40.749567         CASH       6.1        0.0      0.0       0.00
#  7848731  40.752303         Cash       6.2        0.0      0.0       0.00
#
#           Total_Amt                   pick_up_Zone  pick_up_ID  \
#  5232488       6.90                       Gramercy       107.0
#  5232489       7.10                 Yorkville East       262.0
#  5232490      23.95                   West Village       249.0
#  5232491      23.30          Upper West Side South       239.0
#  5232492       6.90   Penn Station/Madison Sq West       186.0
#  ...            ...                            ...         ...
#  7848727      12.10   Penn Station/Madison Sq West       186.0
#  7848728       9.40                       Kips Bay       137.0
#  7848729       6.30  Sutton Place/Turtle Bay North       229.0
#  7848730       6.10                       Flatiron        90.0
#  7848731       6.20                   Clinton East        48.0
#
#                       drop_off_Zone  drop_off_ID
#  5232488             Midtown Center        161.0
#  5232489            Lenox Hill East        140.0
#  5232490           Sunset Park West        228.0
#  5232491                       SoHo        211.0
#  5232492                   Union Sq        234.0
#  ...                            ...          ...
#  7848727        Lincoln Square East        142.0
#  7848728    Greenwich Village North        113.0
#  7848729      Upper East Side South        237.0
#  7848730                Murray Hill        170.0
#  7848731  West Chelsea/Hudson Yards        246.0
#
#  [2616245 rows x 19 columns],
#           vendor_name  Trip_Pickup_DateTime  Trip_Dropoff_DateTime  \
#  7848732          VTS                     9                     10
#  7848733          VTS                    16                     17
#  7848734          VTS                     8                      8
#  7848735          VTS                    14                     14
#  7848736          VTS                    20                     20
#  ...              ...                   ...                    ...
#  10464971         CMT                    21                     21
#  10464972         CMT                    21                     21
#  10464973         CMT                     1                      1
#  10464974         CMT                    23                      0
#  10464975         CMT                    12                     12
#
#            Passenger_Count  Trip_Distance  Start_Lon  Start_Lat    End_Lon  \
#  7848732                 1           0.78 -73.997843  40.745090 -73.985162
#  7848733                 5           1.81 -73.999533  40.711960 -73.982612
#  7848734                 1           1.79 -73.984497  40.728900 -73.980697
#  7848735                 1           0.95 -73.980975  40.781983 -73.972052
#  7848736                 2           4.66 -73.987842  40.727845 -73.946932
#  ...                   ...            ...        ...        ...        ...
#  10464971                1           5.40 -74.006909  40.706041 -73.970295
#  10464972                1           0.90 -73.982273  40.756841 -73.986418
#  10464973                1           1.70 -73.999620  40.728371 -74.011543
#  10464974                2           5.10 -73.977071  40.787890 -73.989669
#  10464975                1           0.40 -73.957029  40.765855 -73.963685
#
#              End_Lat Payment_Type  Fare_Amt  surcharge  Tip_Amt  Tolls_Amt  \
#  7848732   40.739757         CASH       3.7        0.0      0.0        0.0
#  7848733   40.731512         CASH       8.5        0.0      0.0        0.0
#  7848734   40.750905       Credit       8.1        0.0      1.5        0.0
#  7848735   40.793978         CASH       5.3        0.0      0.0        0.0
#  7848736   40.780515       Credit      13.3        0.5      2.0        0.0
#  ...             ...          ...       ...        ...      ...        ...
#  10464971  40.754740       Credit      15.0        0.0      0.0        0.0
#  10464972  40.766582         Cash       5.4        0.0      0.0        0.0
#  10464973  40.708054       Credit       7.0        0.0      1.0        0.0
#  10464974  40.729651         Cash      15.8        0.0      0.0        0.0
#  10464975  40.768296         Cash       4.1        0.0      0.0        0.0
#
#            Total_Amt              pick_up_Zone  pick_up_ID  \
#  7848732         3.7                  Flatiron        90.0
#  7848733         8.5                 Chinatown        45.0
#  7848734         9.6              East Village        79.0
#  7848735         5.3     Upper West Side South       239.0
#  7848736        15.8              East Village        79.0
#  ...             ...                       ...         ...
#  10464971       15.0  Financial District North        87.0
#  10464972        5.4            Midtown Center       161.0
#  10464973        8.0   Greenwich Village South       114.0
#  10464974       15.8     Upper West Side South       239.0
#  10464975        4.1           Lenox Hill East       140.0
#
#                    drop_off_Zone  drop_off_ID
#  7848732                Gramercy        107.0
#  7848733                Gramercy        107.0
#  7848734             Murray Hill        170.0
#  7848735   Upper West Side North        238.0
#  7848736          Yorkville West        263.0
#  ...                         ...          ...
#  10464971    UN/Turtle Bay South        233.0
#  10464972           Clinton East         48.0
#  10464973     World Trade Center        261.0
#  10464974           East Village         79.0
#  10464975  Upper East Side South        237.0
#
#  [2616244 rows x 19 columns],
#           vendor_name  Trip_Pickup_DateTime  Trip_Dropoff_DateTime  \
#  10464976         VTS                    19                     19
#  10464977         VTS                    15                     16
#  10464978         CMT                    15                     15
#  10464979         VTS                    18                     18
#  10464980         CMT                     0                      1
#  ...              ...                   ...                    ...
#  13081215         VTS                    22                     22
#  13081216         VTS                     8                      8
#  13081217         VTS                     8                      9
#  13081218         VTS                    23                      0
#  13081219         VTS                     8                      8
#
#            Passenger_Count  Trip_Distance  Start_Lon  Start_Lat    End_Lon  \
#  10464976                1           1.58 -73.984125  40.740217 -73.970538
#  10464977                1          11.74 -74.003953  40.707335 -73.870787
#  10464978                1           2.60 -73.949201  40.781748 -73.979662
#  10464979                2           1.15 -73.960750  40.757438 -73.978702
#  10464980                1           8.60 -73.982074  40.762315 -73.993533
#  ...                   ...            ...        ...        ...        ...
#  13081215                1           1.69 -73.994683  40.734633 -73.982575
#  13081216                1           3.70 -73.958633  40.783972 -73.992403
#  13081217                2           3.41 -73.962507  40.766962 -73.996218
#  13081218                1           3.43 -73.967777  40.758707 -74.005783
#  13081219                1           1.47 -74.006590  40.731683 -73.994678
#
#              End_Lat Payment_Type  Fare_Amt  surcharge  Tip_Amt  Tolls_Amt  \
#  10464976  40.756075         CASH       6.5        1.0     0.00        0.0
#  10464977  40.774012         CASH      28.1        0.0     0.00        0.0
#  10464978  40.765482         Cash       9.3        0.0     0.00        0.0
#  10464979  40.765645         CASH       6.9        1.0     0.00        0.0
#  10464980  40.661404         Cash      22.2        0.0     0.00        0.0
#  ...             ...          ...       ...        ...      ...        ...
#  13081215  40.719675         CASH       8.1        0.5     0.00        0.0
#  13081216  40.737590         CASH      12.5        0.0     0.00        0.0
#  13081217  40.736315       Credit      16.1        0.0     3.22        0.0
#  13081218  40.731683         CASH      11.7        0.5     0.00        0.0
#  13081219  40.750412         CASH       5.7        0.0     0.00        0.0
#
#            Total_Amt                   pick_up_Zone  pick_up_ID  \
#  10464976       7.50                       Gramercy       107.0
#  10464977      28.10                        Seaport       209.0
#  10464978       9.30                 Yorkville West       263.0
#  10464979       7.90  Sutton Place/Turtle Bay North       229.0
#  10464980      22.20      Times Sq/Theatre District       230.0
#  ...             ...                            ...         ...
#  13081215       8.60        Greenwich Village North       113.0
#  13081216      12.50          Upper East Side North       236.0
#  13081217      19.32                Lenox Hill West       141.0
#  13081218      12.20  Sutton Place/Turtle Bay North       229.0
#  13081219       5.70                   West Village       249.0
#
#                            drop_off_Zone  drop_off_ID
#  10464976  Sutton Place/Turtle Bay North        229.0
#  10464977              LaGuardia Airport        138.0
#  10464978                  Midtown North        163.0
#  10464979                  Midtown North        163.0
#  10464980               Sunset Park West        228.0
#  ...                                 ...          ...
#  13081215        Two Bridges/Seward Park        232.0
#  13081216                       Union Sq        234.0
#  13081217        Greenwich Village North        113.0
#  13081218                   West Village        249.0
#  13081219   Penn Station/Madison Sq West        186.0
#
#  [2616244 rows x 19 columns],
#           vendor_name  Trip_Pickup_DateTime  Trip_Dropoff_DateTime  \
#  13081220         CMT                    17                     17
#  13081221         VTS                    11                     11
#  13081222         VTS                     0                      0
#  13081223         VTS                     9                      9
#  13081224         VTS                     8                      9
#  ...              ...                   ...                    ...
#  15697459         CMT                    13                     13
#  15697460         CMT                     9                     10
#  15697461         CMT                     9                     10
#  15697462         CMT                     6                      6
#  15697463         CMT                    10                     10
#
#            Passenger_Count  Trip_Distance  Start_Lon  Start_Lat    End_Lon  \
#  13081220                1           1.70 -73.974831  40.777610 -73.955195
#  13081221                3           1.01 -73.990478  40.751563 -73.978810
#  13081222                5           1.50 -73.985272  40.727638 -73.983572
#  13081223                1           0.44 -73.987140  40.774995 -73.982142
#  13081224                2          12.40 -73.885327  40.773053 -73.981540
#  ...                   ...            ...        ...        ...        ...
#  15697459                1           0.50 -73.989697  40.739583 -73.983904
#  15697460                1           3.00 -73.978842  40.777230 -73.987625
#  15697461                1           3.70 -73.974583  40.793003 -73.994940
#  15697462                1           5.20 -73.957066  40.770532 -74.009971
#  15697463                1           0.80 -73.990134  40.756090 -73.981894
#
#              End_Lat Payment_Type  Fare_Amt  surcharge  Tip_Amt  Tolls_Amt  \
#  13081220  40.783246         Cash       8.3        0.0     0.00       0.00
#  13081221  40.749468         CASH       6.1        0.0     0.00       0.00
#  13081222  40.744025         CASH       5.7        0.5     0.00       0.00
#  13081223  40.771117         CASH       3.3        0.0     0.00       0.00
#  13081224  40.745007         CASH      30.5        0.0     0.00       4.15
#  ...             ...          ...       ...        ...      ...        ...
#  15697459  40.743671       Credit       4.5        0.0     1.12       0.00
#  15697460  40.739746         Cash      10.5        0.0     0.00       0.00
#  15697461  40.750106       Credit      13.3        0.0     3.32       0.00
#  15697462  40.721202       Credit      15.7        0.0     2.00       0.00
#  15697463  40.763630         Cash       4.5        0.0     0.00       0.00
#
#            Total_Amt           pick_up_Zone  pick_up_ID  \
#  13081220       8.30           Central Park        43.0
#  13081221       6.10       Garment District       100.0
#  13081222       6.20           East Village        79.0
#  13081223       3.30    Lincoln Square West       143.0
#  13081224      34.65      LaGuardia Airport       138.0
#  ...             ...                    ...         ...
#  15697459       5.62               Union Sq       234.0
#  15697460      10.50    Lincoln Square East       142.0
#  15697461      16.62  Upper West Side North       238.0
#  15697462      17.70        Lenox Hill West       141.0
#  15697463       4.50       Garment District       100.0
#
#                           drop_off_Zone  drop_off_ID
#  13081220         Upper East Side North        236.0
#  13081221                   Murray Hill        170.0
#  13081222                 Midtown South        164.0
#  13081223           Lincoln Square East        142.0
#  13081224                   Murray Hill        170.0
#  ...                                ...          ...
#  15697459                 Midtown South        164.0
#  15697460                      Union Sq        234.0
#  15697461  Penn Station/Madison Sq West        186.0
#  15697462          TriBeCa/Civic Center        231.0
#  15697463     Times Sq/Theatre District        230.0
#
#  [2616244 rows x 19 columns],
#           vendor_name  Trip_Pickup_DateTime  Trip_Dropoff_DateTime  \
#  15697464         CMT                    14                     14
#  15697465         CMT                    14                     14
#  15697466         CMT                    22                     22
#  15697467         CMT                    21                     22
#  15697468         CMT                     8                      8
#  ...              ...                   ...                    ...
#  18313703         VTS                     1                      1
#  18313704         VTS                    11                     11
#  18313705         VTS                     9                      9
#  18313706         VTS                     0                      0
#  18313707         VTS                    15                     15
#
#            Passenger_Count  Trip_Distance  Start_Lon  Start_Lat    End_Lon  \
#  15697464                1           7.10 -73.962834  40.767282 -73.928540
#  15697465                1           1.60 -73.991197  40.749069 -74.000349
#  15697466                2           1.20 -73.964441  40.764700 -73.964400
#  15697467                2           1.40 -73.988384  40.731301 -73.997410
#  15697468                2           1.10 -73.966730  40.793431 -73.965525
#  ...                   ...            ...        ...        ...        ...
#  18313703                5           2.04 -74.000053  40.718298 -73.980292
#  18313704                1           1.37 -73.985083  40.754232 -73.991050
#  18313705                1           1.29 -73.958347  40.766333 -73.974067
#  18313706                5           3.72 -73.984480  40.736983 -74.004533
#  18313707                2           0.70 -74.000078  40.748177 -73.990757
#
#              End_Lat Payment_Type  Fare_Amt  surcharge  Tip_Amt  Tolls_Amt  \
#  15697464  40.851401       Credit      20.9        0.0      3.0        0.0
#  15697465  40.728673         Cash       8.1        0.0      0.0        0.0
#  15697466  40.753963         Cash       5.4        0.0      0.0        0.0
#  15697467  40.744547         Cash       7.0        0.0      0.0        0.0
#  15697468  40.805472         Cash       6.1        0.0      0.0        0.0
#  ...             ...          ...       ...        ...      ...        ...
#  18313703  40.728653       Credit       8.9        0.5      0.6        0.0
#  18313704  40.747882         CASH       5.7        0.0      0.0        0.0
#  18313705  40.762292       Credit       6.5        0.0      1.5        0.0
#  18313706  40.707303       Credit      10.9        0.5      1.0        0.0
#  18313707  40.742878         CASH       4.5        0.0      0.0        0.0
#
#            Total_Amt                  pick_up_Zone  pick_up_ID  \
#  15697464       23.9         Upper East Side South       237.0
#  15697465        8.1  Penn Station/Madison Sq West       186.0
#  15697466        5.4         Upper East Side South       237.0
#  15697467        7.0                  East Village        79.0
#  15697468        6.1         Upper West Side North       238.0
#  ...             ...                           ...         ...
#  18313703       10.0           Little Italy/NoLiTa       144.0
#  18313704        5.7              Garment District       100.0
#  18313705        8.0               Lenox Hill West       141.0
#  18313706       12.4                      Gramercy       107.0
#  18313707        4.5                  East Chelsea        68.0
#
#                            drop_off_Zone  drop_off_ID
#  15697464       Washington Heights North        243.0
#  15697465        Greenwich Village South        114.0
#  15697466  Sutton Place/Turtle Bay North        229.0
#  15697467                       Flatiron         90.0
#  15697468            Morningside Heights        166.0
#  ...                                 ...          ...
#  18313703                   East Village         79.0
#  18313704   Penn Station/Madison Sq West        186.0
#  18313705                  Midtown North        163.0
#  18313706       Financial District North         87.0
#  18313707                       Union Sq        234.0
#
#  [2616244 rows x 19 columns],
#           vendor_name  Trip_Pickup_DateTime  Trip_Dropoff_DateTime  \
#  18313708         VTS                     2                      2
#  18313709         VTS                     3                      4
#  18313710         VTS                    20                     21
#  18313711         VTS                     0                      0
#  18313712         VTS                     2                      2
#  ...              ...                   ...                    ...
#  20929947         VTS                    21                     21
#  20929948         VTS                    21                     21
#  20929949         VTS                    19                     20
#  20929950         VTS                    20                     20
#  20929951         VTS                    19                     19
#
#            Passenger_Count  Trip_Distance  Start_Lon  Start_Lat    End_Lon  \
#  18313708                4           2.12 -74.005872  40.740112 -73.985258
#  18313709                5           8.96 -73.989477  40.740078 -73.897598
#  18313710                1           2.24 -73.992668  40.768600 -73.991083
#  18313711                5           0.85 -73.974665  40.755620 -73.978500
#  18313712                1           3.06 -73.992862  40.731588 -73.978220
#  ...                   ...            ...        ...        ...        ...
#  20929947                6           7.16 -73.972657  40.746172 -73.997905
#  20929948                5           5.39 -73.988675  40.736945 -73.958742
#  20929949                2           6.76 -73.972813  40.785552 -73.989310
#  20929950                1          12.64 -73.874460  40.774097 -74.016488
#  20929951                4           1.97 -73.986772  40.750775 -73.964108
#
#              End_Lat Payment_Type  Fare_Amt  surcharge  Tip_Amt  Tolls_Amt  \
#  18313708  40.763393         CASH       6.9        0.5     0.00        0.0
#  18313709  40.824405         CASH      24.9        0.5     0.00        0.0
#  18313710  40.744995         CASH       7.7        0.5     0.00        0.0
#  18313711  40.745923       Credit       4.1        0.5     1.00        0.0
#  18313712  40.762915         CASH       8.9        0.5     0.00        0.0
#  ...             ...          ...       ...        ...      ...        ...
#  20929947  40.678167         CASH      19.3        0.5     0.00        0.0
#  20929948  40.800042         CASH      16.5        0.5     0.00        0.0
#  20929949  40.723593         CASH      17.7        0.0     0.00        0.0
#  20929950  40.711360       Credit      29.7        0.5     7.55        0.0
#  20929951  40.754688         CASH      10.1        0.0     0.00        0.0
#
#            Total_Amt                   pick_up_Zone  pick_up_ID  \
#  18313708       7.40  Meatpacking/West Village West       158.0
#  18313709      25.40                       Union Sq       234.0
#  18313710       8.20                   Clinton West        50.0
#  18313711       5.60                   Midtown East       162.0
#  18313712       9.40        Greenwich Village North       113.0
#  ...             ...                            ...         ...
#  20929947      19.80                    Murray Hill       170.0
#  20929948      17.00                       Gramercy       107.0
#  20929949      17.70          Upper West Side South       239.0
#  20929950      37.75              LaGuardia Airport       138.0
#  20929951      10.10                  Midtown South       164.0
#
#                            drop_off_Zone  drop_off_ID
#  18313708      Times Sq/Theatre District        230.0
#  18313709                       Longwood        147.0
#  18313710                       Union Sq        234.0
#  18313711                    Murray Hill        170.0
#  18313712                  Midtown North        163.0
#  ...                                 ...          ...
#  20929947                Carroll Gardens         40.0
#  20929948                   Bloomingdale         24.0
#  20929949                   East Village         79.0
#  20929950              Battery Park City         13.0
#  20929951  Sutton Place/Turtle Bay North        229.0
#
#  [2616244 rows x 19 columns],
#           vendor_name  Trip_Pickup_DateTime  Trip_Dropoff_DateTime  \
#  20929952         VTS                     9                      9
#  20929953         VTS                    16                     16
#  20929954         VTS                     7                      7
#  20929955         VTS                    16                     16
#  20929956         VTS                     1                      1
#  ...              ...                   ...                    ...
#  23546191         VTS                    18                     18
#  23546192         VTS                    19                     19
#  23546193         VTS                    13                     13
#  23546194         VTS                     8                      8
#  23546195         VTS                    23                     23
#
#            Passenger_Count  Trip_Distance  Start_Lon  Start_Lat    End_Lon  \
#  20929952                1           5.14 -73.991165  40.765960 -74.017205
#  20929953                2           2.43 -73.982465  40.771652 -73.973542
#  20929954                1           1.17 -73.973277  40.759668 -73.976432
#  20929955                1           3.50 -73.962358  40.770183 -73.996118
#  20929956                1           2.66 -73.994693  40.766197 -73.969473
#  ...                   ...            ...        ...        ...        ...
#  23546191                1           0.47 -73.954257  40.764195 -73.960275
#  23546192                2           0.77 -73.954290  40.765627 -73.961758
#  23546193                5           0.98 -73.978868  40.782095 -73.978868
#  23546194                1           0.81 -73.961787  40.776975 -73.954167
#  23546195                1           5.54 -73.976578  40.755157 -74.007153
#
#              End_Lat Payment_Type  Fare_Amt  surcharge  Tip_Amt  Tolls_Amt  \
#  20929952  40.705247       Credit      15.7        0.0      4.0        0.0
#  20929953  40.747982         CASH       8.9        0.0      0.0        0.0
#  20929954  40.748105         CASH       7.7        0.0      0.0        0.0
#  20929955  40.732987         CASH      11.7        0.0      0.0        0.0
#  20929956  40.798895       Credit       9.7        0.5      0.0        0.0
#  ...             ...          ...       ...        ...      ...        ...
#  23546191  40.762138         CASH       4.1        1.0      0.0        0.0
#  23546192  40.756093       Credit       4.5        1.0      0.5        0.0
#  23546193  40.782095         CASH       5.3        0.0      0.0        0.0
#  23546194  40.786917         CASH       4.1        0.0      0.0        0.0
#  23546195  40.705273         CASH      14.9        0.5      0.0        0.0
#
#            Total_Amt           pick_up_Zone  pick_up_ID  \
#  20929952       19.7           Clinton West        50.0
#  20929953        8.9    Lincoln Square East       142.0
#  20929954        7.7         Midtown Center       161.0
#  20929955       11.7  Upper East Side South       237.0
#  20929956       10.2           Clinton West        50.0
#  ...             ...                    ...         ...
#  23546191        5.1        Lenox Hill East       140.0
#  23546192        6.0        Lenox Hill East       140.0
#  23546193        5.3  Upper West Side South       239.0
#  23546194        4.1  Upper East Side North       236.0
#  23546195       15.4         Midtown Center       161.0
#
#                            drop_off_Zone  drop_off_ID
#  20929952              Battery Park City         13.0
#  20929953            UN/Turtle Bay South        233.0
#  20929954                    Murray Hill        170.0
#  20929955        Greenwich Village North        113.0
#  20929956               Manhattan Valley        151.0
#  ...                                 ...          ...
#  23546191                Lenox Hill West        141.0
#  23546192  Sutton Place/Turtle Bay North        229.0
#  23546193          Upper West Side South        239.0
#  23546194          Upper East Side North        236.0
#  23546195       Financial District North         87.0
#
#  [2616244 rows x 19 columns],
#           vendor_name  Trip_Pickup_DateTime  Trip_Dropoff_DateTime  \
#  23546196         VTS                    10                     11
#  23546197         VTS                    13                     13
#  23546198         VTS                    11                     11
#  23546199         VTS                    13                     13
#  23546200         VTS                    15                     15
#  ...              ...                   ...                    ...
#  26162435         DDS                    20                     20
#  26162436         DDS                    13                     13
#  26162437         DDS                    18                     18
#  26162438         DDS                    16                     16
#  26162439         VTS                    10                     11
#
#            Passenger_Count  Trip_Distance  Start_Lon  Start_Lat    End_Lon  \
#  23546196                1           1.63 -73.953650  40.787988 -73.970428
#  23546197                5           0.87 -73.969038  40.790648 -73.976648
#  23546198                1           1.16 -73.996297  40.741028 -74.005477
#  23546199                1           0.73 -73.974583  40.761932 -73.983482
#  23546200                2           2.94 -73.991122  40.750497 -73.965392
#  ...                   ...            ...        ...        ...        ...
#  26162435                1           1.40 -73.993691  40.727382 -74.008023
#  26162436                1           0.80 -73.956832  40.770792 -73.968771
#  26162437                1           1.30 -73.982368  40.763115 -73.979028
#  26162438                1           1.20 -73.991986  40.749266 -73.978223
#  26162439                2           2.32 -73.991867  40.726030 -73.987728
#
#              End_Lat Payment_Type  Fare_Amt  surcharge  Tip_Amt  Tolls_Amt  \
#  23546196  40.784917       Credit       6.5        0.0      1.0        0.0
#  23546197  40.780322         CASH       4.5        0.0      0.0        0.0
#  23546198  40.750952       Credit       5.3        0.0      2.0        0.0
#  23546199  40.759347         CASH       4.9        0.0      0.0        0.0
#  23546200  40.774183         CASH      10.1        0.0      0.0        0.0
#  ...             ...          ...       ...        ...      ...        ...
#  26162435  40.738181         CASH       6.1        0.5      0.0        0.0
#  26162436  40.768191         CASH       5.7        0.0      0.0        0.0
#  26162437  40.750020       CREDIT       7.7        1.0      1.7        0.0
#  26162438  40.752406         CASH       6.5        0.0      0.0        0.0
#  26162439  40.769512         CASH      12.1        0.0      0.0        0.0
#
#            Total_Amt                  pick_up_Zone  pick_up_ID  \
#  23546196        7.5             East Harlem South        75.0
#  23546197        4.5         Upper West Side North       238.0
# ...
#  34011170                1           7.40 -73.977952  40.783440 -73.992008
#  34011171                3           3.40 -73.989167  40.718478 -74.002234
#
#              End_Lat Payment_Type  Fare_Amt  surcharge  Tip_Amt  Tolls_Amt  \
#  31394928  40.713463         CASH      10.5        0.0      0.0        0.0
#  31394929  40.780072       Credit      11.3        0.0      3.0        0.0
#  31394930  40.744342       Credit      12.9        0.5      0.0        0.0
#  31394931  40.814410         CASH      16.9        0.0      0.0        0.0
#  31394932  40.752383         CASH      10.1        0.0      0.0        0.0
#  ...             ...          ...       ...        ...      ...        ...
#  34011167  40.761272         Cash       6.9        0.0      0.0        0.0
#  34011168  40.758303         Cash       7.9        0.0      0.0        0.0
#  34011169  40.725620       Credit       9.9        0.0      4.0        0.0
#  34011170  40.714458       Credit      19.4        0.0      2.0        0.0
#  34011171  40.750656         Cash      13.0        0.0      0.0        0.0
#
#            Total_Amt                   pick_up_Zone  pick_up_ID  \
#  31394928       10.5               Garment District       100.0
#  31394929       14.3                 Midtown Center       161.0
#  31394930       13.4  Sutton Place/Turtle Bay North       229.0
#  31394931       16.9                  Midtown South       164.0
#  31394932       10.1                Lenox Hill East       140.0
#  ...             ...                            ...         ...
#  34011167        6.9          Upper East Side North       236.0
#  34011168        7.9                       Gramercy       107.0
#  34011169       13.9  Sutton Place/Turtle Bay North       229.0
#  34011170       21.4          Upper West Side South       239.0
#  34011171       13.0                Lower East Side       148.0
#
#                        drop_off_Zone  drop_off_ID
#  31394928                  Chinatown         45.0
#  31394929             Yorkville West        263.0
#  31394930                   Woodside        260.0
#  31394931       Central Harlem North         42.0
#  31394932                Murray Hill        170.0
#  ...                             ...          ...
#  34011167             Midtown Center        161.0
#  34011168             Midtown Center        161.0
#  34011169               East Village         79.0
#  34011170            Lower East Side        148.0
#  34011171  West Chelsea/Hudson Yards        246.0
#
#  [2616244 rows x 19 columns],
#           vendor_name  Trip_Pickup_DateTime  Trip_Dropoff_DateTime  \
#  34011172         CMT                    17                     17
#  34011173         CMT                    11                     11
#  34011174         CMT                     3                      4
#  34011175         CMT                     8                      8
#  34011176         CMT                     8                      8
#  ...              ...                   ...                    ...
#  36627411         VTS                    15                     15
#  36627412         VTS                     8                      8
#  36627413         VTS                    15                     15
#  36627414         VTS                    22                     22
#  36627415         VTS                    10                     10
#
#            Passenger_Count  Trip_Distance  Start_Lon  Start_Lat    End_Lon  \
#  34011172                1           3.90 -73.990982  40.750963 -73.947874
#  34011173                1           2.10 -73.985212  40.756620 -73.972905
#  34011174                2           3.80 -73.987810  40.719962 -73.989866
#  34011175                1           3.20 -73.984921  40.710495 -73.974010
#  34011176                1           0.90 -73.991456  40.750038 -73.979296
#  ...                   ...            ...        ...        ...        ...
#  36627411                1           0.56 -73.995863  40.744198 -73.994033
#  36627412                1           0.58 -73.967895  40.762007 -73.973005
#  36627413                1           1.43 -73.985987  40.777803 -73.972875
#  36627414                1           1.30 -73.980837  40.721408 -74.001708
#  36627415                1           1.14 -73.970470  40.753140 -73.974182
#
#              End_Lat Payment_Type  Fare_Amt  surcharge  Tip_Amt  Tolls_Amt  \
#  34011172  40.778891         Cash      15.1        0.0      0.0        0.0
#  34011173  40.780259         Cash       7.7        0.0      0.0        0.0
#  34011174  40.761430         Cash      11.8        0.0      0.0        0.0
#  34011175  40.748154         Cash       9.3        0.0      0.0        0.0
#  34011176  40.750354         Cash       6.1        0.0      0.0        0.0
#  ...             ...          ...       ...        ...      ...        ...
#  36627411  40.749065         CASH       4.5        0.0      0.0        0.0
#  36627412  40.754615       Credit       4.1        0.0      3.0        0.0
#  36627413  40.795778         CASH       6.1        0.0      0.0        0.0
#  36627414  40.724912         CASH       6.5        0.5      0.0        0.0
#  36627415  40.740548         CASH       5.7        0.0      0.0        0.0
#
#            Total_Amt                  pick_up_Zone  pick_up_ID  \
#  34011172       15.1  Penn Station/Madison Sq West       186.0
#  34011173        7.7     Times Sq/Theatre District       230.0
#  34011174       11.8               Lower East Side       148.0
#  34011175        9.3       Two Bridges/Seward Park       232.0
#  34011176        6.1  Penn Station/Madison Sq West       186.0
#  ...             ...                           ...         ...
#  36627411        4.5                      Flatiron        90.0
#  36627412        7.1                  Midtown East       162.0
#  36627413        6.1           Lincoln Square West       143.0
#  36627414        7.0                 Alphabet City         4.0
#  36627415        5.7           UN/Turtle Bay South       233.0
#
#                           drop_off_Zone  drop_off_ID
#  34011172                Yorkville East        262.0
#  34011173                  Central Park         43.0
#  34011174                  Clinton East         48.0
#  34011175           UN/Turtle Bay South        233.0
#  34011176                   Murray Hill        170.0
#  ...                                ...          ...
#  36627411  Penn Station/Madison Sq West        186.0
#  36627412                  Midtown East        162.0
#  36627413         Upper West Side North        238.0
#  36627414                          SoHo        211.0
#  36627415                      Kips Bay        137.0
#
#  [2616244 rows x 19 columns],
#           vendor_name  Trip_Pickup_DateTime  Trip_Dropoff_DateTime  \
#  36627416         VTS                    13                     13
#  36627417         VTS                    10                     10
#  36627418         VTS                    10                     10
#  36627419         VTS                    14                     14
#  36627420         VTS                    11                     11
#  ...              ...                   ...                    ...
#  39243655         VTS                    18                     18
#  39243656         VTS                    22                     22
#  39243657         VTS                    17                     17
#  39243658         VTS                    17                     17
#  39243659         VTS                    19                     19
#
#            Passenger_Count  Trip_Distance  Start_Lon  Start_Lat    End_Lon  \
#  36627416                5           1.13 -73.992178  40.748690 -73.989413
#  36627417                1           2.48 -73.978053  40.786598 -73.981372
#  36627418                1           2.44 -73.977042  40.729095 -73.985583
#  36627419                2           3.42 -74.011308  40.709063 -73.988740
#  36627420                2           1.60 -74.030600  40.797890 -73.992278
#  ...                   ...            ...        ...        ...        ...
#  39243655                2           4.12 -73.995667  40.724647 -73.959222
#  39243656                1           1.07 -73.974098  40.783872 -73.970120
#  39243657                3           0.51 -73.956385  40.778088 -73.962548
#  39243658                1           2.51 -73.999862  40.732853 -73.977625
#  39243659                1           0.50 -73.961455  40.769422 -73.961608
#
#              End_Lat Payment_Type  Fare_Amt  surcharge  Tip_Amt  Tolls_Amt  \
#  36627416  40.737520         CASH       8.9        0.0      0.0        0.0
#  36627417  40.759185         CASH      10.1        0.0      0.0        0.0
#  36627418  40.753200       Credit       9.3        0.0      2.0        0.0
#  36627419  40.736737         CASH      12.5        0.0      0.0        0.0
#  36627420  40.764073       Credit       5.7        0.0      1.0        0.0
#  ...             ...          ...       ...        ...      ...        ...
#  39243655  40.772358       Credit      13.7        1.0      2.0        0.0
#  39243656  40.789303       Credit       4.9        0.5      1.6        0.0
#  39243657  40.769875         CASH       3.7        1.0      0.0        0.0
#  39243658  40.713350         CASH       9.7        1.0      0.0        0.0
#  39243659  40.764775         CASH       3.3        1.0      0.0        0.0
#
#            Total_Amt                    pick_up_Zone  pick_up_ID  \
#  36627416        8.9    Penn Station/Madison Sq West       186.0
#  36627417       10.1           Upper West Side South       239.0
#  36627418       11.3  Stuy Town/Peter Cooper Village       224.0
#  36627419       12.5              World Trade Center       261.0
#  36627420        6.7                             NaN         NaN
#  ...             ...                             ...         ...
#  39243655       16.7             Little Italy/NoLiTa       144.0
#  39243656        7.0           Upper West Side South       239.0
#  39243657        4.7           Upper East Side North       236.0
#  39243658       10.7         Greenwich Village North       113.0
#  39243659        4.3           Upper East Side South       237.0
#
#                        drop_off_Zone  drop_off_ID
#  36627416                   Union Sq        234.0
#  36627417  Times Sq/Theatre District        230.0
#  36627418           Garment District        100.0
#  36627419                   Gramercy        107.0
#  36627420               Clinton West         50.0
#  ...                             ...          ...
#  39243655      Upper East Side South        237.0
#  39243656      Upper West Side North        238.0
#  39243657      Upper East Side South        237.0
#  39243658    Two Bridges/Seward Park        232.0
#  39243659            Lenox Hill West        141.0
#
#  [2616244 rows x 19 columns],
#           vendor_name  Trip_Pickup_DateTime  Trip_Dropoff_DateTime  \
#  39243660         VTS                    20                     21
#  39243661         VTS                     7                      7
#  39243662         VTS                    18                     18
#  39243663         VTS                    22                     22
#  39243664         VTS                    20                     20
#  ...              ...                   ...                    ...
#  41859899         VTS                    15                     15
#  41859900         CMT                    14                     14
#  41859901         VTS                    14                     14
#  41859902         VTS                    13                     14
#  41859903         CMT                     8                      9
#
#            Passenger_Count  Trip_Distance  Start_Lon  Start_Lat    End_Lon  \
#  39243660                1           2.87 -73.963718  40.761258 -73.998053
#  39243661                1           1.68 -73.978367  40.777930 -73.962942
#  39243662                2           1.90 -73.987395  40.722537 -73.979940
#  39243663                1           7.82 -73.977298  40.789605 -74.007487
#  39243664                3           0.93 -73.975770  40.755162 -73.991643
#  ...                   ...            ...        ...        ...        ...
#  41859899                1           1.76 -74.007233  40.728073 -73.994533
#  41859900                2           0.70 -73.982405  40.775247 -73.978472
#  41859901                5           0.89 -73.982013  40.743330 -73.994328
#  41859902                1           1.94 -73.972788  40.761988 -73.951477
#  41859903                1           3.80 -73.977467  40.751861 -74.009913
#
#              End_Lat Payment_Type  Fare_Amt  surcharge  Tip_Amt  Tolls_Amt  \
#  39243660  40.745183         CASH       9.7        0.5      0.0        0.0
#  39243661  40.766753         CASH       6.9        0.0      0.0        0.0
#  39243662  40.740827         CASH       7.3        0.0      0.0        0.0
#  39243663  40.707028       Credit      20.1        0.5      3.0        0.0
#  39243664  40.759005       Credit       4.5        0.5      0.5        0.0
#  ...             ...          ...       ...        ...      ...        ...
#  41859899  40.750588       Credit       6.5        0.0      2.0        0.0
#  41859900  40.782864       Credit       5.3        0.0      1.1        0.0
#  41859901  40.750130         CASH       6.5        0.0      0.0        0.0
#  41859902  40.778217       Credit       8.1        0.0      1.9        0.0
#  41859903  40.713470         Cash      14.5        0.0      0.0        0.0
#
#            Total_Amt           pick_up_Zone  pick_up_ID  \
#  39243660       10.2        Lenox Hill West       141.0
#  39243661        6.9    Lincoln Square East       142.0
#  39243662        7.3        Lower East Side       148.0
#  39243663       23.6  Upper West Side North       238.0
#  39243664        5.5         Midtown Center       161.0
#  ...             ...                    ...         ...
#  41859899        8.5              Hudson Sq       125.0
#  41859900        6.4    Lincoln Square East       142.0
#  41859901        6.5            Murray Hill       170.0
#  41859902       10.0          Midtown North       163.0
#  41859903       14.5            Murray Hill       170.0
#
#                           drop_off_Zone  drop_off_ID
#  39243660                      Flatiron         90.0
#  39243661         Upper East Side South        237.0
#  39243662                      Kips Bay        137.0
#  39243663      Financial District North         87.0
#  39243664                  Clinton East         48.0
#  ...                                ...          ...
#  41859899  Penn Station/Madison Sq West        186.0
#  41859900         Upper West Side South        239.0
#  41859901  Penn Station/Madison Sq West        186.0
#  41859902                Yorkville West        263.0
#  41859903          TriBeCa/Civic Center        231.0
#
#  [2616244 rows x 19 columns],
#           vendor_name  Trip_Pickup_DateTime  Trip_Dropoff_DateTime  \
#  41859904         VTS                    23                     23
#  41859905         CMT                    14                     15
#
#            Passenger_Count  Trip_Distance  Start_Lon  Start_Lat    End_Lon  \
#  41859904                3           3.85 -73.981295     40.753 -73.949453
#  41859905                1          17.30   0.000000      0.000   0.000000
#
#             End_Lat Payment_Type  Fare_Amt  surcharge  Tip_Amt  Tolls_Amt  \
#  41859904  40.77952         CASH      10.9        0.5      0.0        0.0
#  41859905   0.00000       Credit      45.0        0.0      5.0        0.0
#
#            Total_Amt   pick_up_Zone  pick_up_ID   drop_off_Zone  drop_off_ID
#  41859904       11.4  Midtown South       164.0  Yorkville West        263.0
#  41859905       50.0            NaN         NaN             NaN          NaN  ]

# %%
new_frame = pd.concat(list_frame)
new_frame.to_csv('Finish_mapping.csv')

# %%
new_frame
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_26322/932471988.py in <module>
#       1 new_frame
# ----> 2 frame = dt.fread(new_frame)
#
# /opt/conda/lib/python3.8/site-packages/datatable/utils/fread.py in _resolve_source_any(src, tempfiles)
#     126         return _resolve_source_list(src, tempfiles)
#     127     else:
# --> 128         raise TypeError("Unknown type for the first argument in fread: %r"
#     129                         % type(src))
#     130
#
# TypeError: Unknown type for the first argument in fread: <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
frame = dt.fread('Finish_mapping.csv')

# %%
frame
# Out:
# <Frame#7f2aa0b7dd80 41859908x20>

# %%
frame[:,dt.count(), by('pick_up_Zone')].sort(-f.count)
# Out:
# <Frame#7f2b30583930 261x2>

# %%
frame[:,dt.count(), by('drop_off_Zone')].sort(-f.count)
# Out:
# <Frame#7f2593f11ea0 261x2>

# %%
frame[:, dt.count(), by('pick_up_Zone', 'drop_off_Zone')].sort(-f.count)
# Out:
# <Frame#7f2b30583870 36421x3>

# %%
frame[:, dt.count(), by('Trip_Pickup_DateTime')]
# Out:
# <Frame#7f26d9c17060 24x2>

# %%
frame[:, dt.count(), by('Trip_Dropoff_DateTime')]
# Out:
# <Frame#7f2593f11fc0 24x2>
